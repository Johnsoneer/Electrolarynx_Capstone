# %%
import os
os.chdir("..")
from source.pipeline import pipeline
import IPython.display as ipd

# %%
pipe = pipeline()
test_video = "UVaVoice/Participant 1/Electrolarynx/10.mp4"

# %%
# Show our waveform normalized
pipe.print_audio(test_video)

# %%
# show our audio as a matrix
array_example, test_audioclip = pipe.get_audio(test_video)
array_example
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00],
#        [ 3.05175781e-05,  3.05175781e-05],
#        [ 3.05175781e-05,  3.05175781e-05],
#        ...,
#        [-2.41088867e-03, -2.41088867e-03],
#        [ 4.57763672e-04,  4.57763672e-04],
#        [ 2.13623047e-04,  2.13623047e-04]])

# %%
# display our audio file so we can play it.
test_audioclip.ipython_display()
# Out:
# chunk:   8%|▊         | 76/917 [00:00<00:01, 742.41it/s, now=None]
# MoviePy - Writing audio in __temp__.mp3
# MoviePy - Done.
# <div align=middle><audio controls><source   src='data:audio/mp3;base64,...'>Sorry, seems like your browser doesn't support HTML5 audio/video</audio></div>

# %%
# Run this to remove that temporary file saved in the repo 
os.remove("__temp__.mp3")

# %%
# TODO: run an open-source STT model on the above example.
